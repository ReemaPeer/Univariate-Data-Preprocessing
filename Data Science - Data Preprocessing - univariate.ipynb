# %% [markdown]
# # Placement Dataset

# %%
# Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset

dataset = pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# Getting the dataset information

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
# sl_no             215 non-null int64
# gender            215 non-null object
# ssc_p             215 non-null float64
# ssc_b             215 non-null object
# hsc_p             215 non-null float64
# hsc_b             215 non-null object
# hsc_s             215 non-null object
# degree_p          215 non-null float64
# degree_t          215 non-null object
# workex            215 non-null object
# etest_p           215 non-null float64
# specialisation    215 non-null object
# mba_p             215 non-null float64
# status            215 non-null object
# salary            148 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# # Data Preprocessing

# %%
# Checking for the number of null values in each column of the dataset

dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
# Filling the null values in salary column with 0

dataset['salary'].fillna(0, inplace = True)

# %%
# Checking the dataset for update

dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # Filling the null values automatically using Imputer

# %%
dataset = pd.read_csv('placement.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# Splitting the qualitative and quantitative data

def QuanQual(dataset):
    
    Qual = []
    Quan = []

    for col in dataset.columns:
        if dataset[col].dtype == 'O':
            Qual.append(col)
        else:
            Quan.append(col)
    return Quan,Qual

# %%
Quan,Qual = QuanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
# Filling the missing values using the Imputer

from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values = np.nan, strategy = 'constant')
imp.fit(dataset[Quan])
df = imp.transform(dataset[Quan])
df = pd.DataFrame(df, columns = Quan)
df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
# Checking for the null values 

df.isnull().sum()
# Out:
# sl_no       0
# ssc_p       0
# hsc_p       0
# degree_p    0
# etest_p     0
# mba_p       0
# salary      0
# dtype: int64

# %%
df1 = dataset[Qual]
df1
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
frame = [df,df1]

# %%
preprocessed_data = pd.concat(frame, axis = 1)
preprocessed_data
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
preprocessed_data.to_csv("Placement_Processed.csv", index = False)

# %%
# Reading the preprocessed dataset

data = pd.read_csv("Placement_Processed.csv")
data
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
# getting the data information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
# sl_no             215 non-null float64
# ssc_p             215 non-null float64
# hsc_p             215 non-null float64
# degree_p          215 non-null float64
# etest_p           215 non-null float64
# mba_p             215 non-null float64
# salary            215 non-null float64
# gender            215 non-null object
# ssc_b             215 non-null object
# hsc_b             215 non-null object
# hsc_s             215 non-null object
# degree_t          215 non-null object
# workex            215 non-null object
# specialisation    215 non-null object
# status            215 non-null object
# dtypes: float64(7), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# # Central Tendency

# %%
# Getting the description of the dataset

data.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
# calculating the Mean, Median and Mode Manually

data.mean()
# Out:
# sl_no          108.000000
# ssc_p           67.303395
# hsc_p           66.333163
# degree_p        66.370186
# etest_p         72.100558
# mba_p           62.278186
# salary      198702.325581
# dtype: float64

# %%
data.median()
# Out:
# sl_no          108.0
# ssc_p           67.0
# hsc_p           65.0
# degree_p        66.0
# etest_p         71.0
# mba_p           62.0
# salary      240000.0
# dtype: float64

# %%
data['ssc_p'].mode()[0]
# Out:
# 62.0

# %%
# Creating the table for description

description = pd.DataFrame(index = ['Mean', 'Median', 'Mode'], columns = Quan)
description
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
# Filling the corresponding values in the description table

for col in Quan:
    description[col]['Mean'] = data[col].mean()
    description[col]['Median'] = data[col].median()
    description[col]['Mode'] = data[col].mode()[0]

# %%
description
# Out:
#        sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Mean     108  67.3034  66.3332  66.3702  72.1006  62.2782  198702
# Median   108       67       65       66       71       62  240000
# Mode       1       62       63       65       60     56.7       0

# %% [markdown]
# # Percentile

# %%
# Getting the data description

data.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
# calculating the percentile manually

np.percentile(data['ssc_p'],25)
# Out:
# 60.599999999999994

# %%
# Creating the table for data description manually

description = pd.DataFrame(index = ['Mean', 'Median', 'Mode', 'Q1-25%', 'Q2-50%', 'Q3-75%', '99%', 'Q4-100%'], columns = Quan)
description
# Out:
#         sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean      NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode      NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1-25%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2-50%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3-75%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 99%       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4-100%   NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
# Filling the percentile values in description from descriptive table

for col in Quan:
    description[col]['Mean'] = data[col].mean()
    description[col]['Median'] = data[col].median()
    description[col]['Mode'] = data[col].mode()[0]
    description[col]['Q1-25%'] = data.describe()[col]['25%']
    description[col]['Q2-50%'] = data.describe()[col]['50%']
    description[col]['99%'] = np.percentile(data[col],99)
    description[col]['Q3-75%'] = data.describe()[col]['75%']
    description[col]['Q4-100%'] = data.describe()[col]['max']

# %%
description
# Out:
#           sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Mean        108  67.3034  66.3332  66.3702  72.1006  62.2782  198702
# Median      108       67       65       66       71       62  240000
# Mode          1       62       63       65       60     56.7       0
# Q1-25%     54.5     60.6     60.9       61       60   57.945       0
# Q2-50%      108       67       65       66       71       62  240000
# Q3-75%    161.5     75.7       73       72     83.5   66.255  282500
# 99%      212.86       87    91.86    83.86       97  76.1142  629000
# Q4-100%     215     89.4     97.7       91       98    77.89  940000

# %%
# Filling the descriptive table with respective values manually

for col in Quan:
    description[col]['Mean'] = data[col].mean()
    description[col]['Median'] = data[col].median()
    description[col]['Mode'] = data[col].mode()[0]
    description[col]['Q1-25%'] = np.percentile(data[col],25)
    description[col]['Q2-50%'] = np.percentile(data[col],50)
    description[col]['99%'] = np.percentile(data[col],99)
    description[col]['Q3-75%'] = np.percentile(data[col],75)
    description[col]['Q4-100%'] = np.percentile(data[col],100)

# %%
description
# Out:
#           sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Mean        108  67.3034  66.3332  66.3702  72.1006  62.2782  198702
# Median      108       67       65       66       71       62  240000
# Mode          1       62       63       65       60     56.7       0
# Q1-25%     54.5     60.6     60.9       61       60   57.945       0
# Q2-50%      108       67       65       66       71       62  240000
# Q3-75%    161.5     75.7       73       72     83.5   66.255  282500
# 99%      212.86       87    91.86    83.86       97  76.1142  629000
# Q4-100%     215     89.4     97.7       91       98    77.89  940000

# %% [markdown]
# # InterQuartile Range
#       Formulas:
#          IQR = Q3 -Q1
#          Lesser Outlier = Q1 - (1.5)*IQR
#          Greater Outlier = Q3 + (1.5)*IQR

# %%
# Creating the table for data description manually

description = pd.DataFrame(index = ['Mean', 'Median', 'Mode', 'Q1-25%', 'Q2-50%', 'Q3-75%', '99%', 'Q4-100%', 'IQR', 
                                   'Lesser', 'Greater', '1.5Range', 'Min', 'Max'], columns = Quan)
description
# Out:
#          sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1-25%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2-50%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3-75%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 99%        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4-100%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# IQR        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Lesser     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Greater    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 1.5Range   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Min        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Max        NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
# Filling the descriptive table with respective values

for col in Quan:
    description[col]['Mean'] = data[col].mean()
    description[col]['Median'] = data[col].median()
    description[col]['Mode'] = data[col].mode()[0]
    description[col]['Q1-25%'] = np.percentile(data[col],25)
    description[col]['Q2-50%'] = np.percentile(data[col],50)
    description[col]['99%'] = np.percentile(data[col],99)
    description[col]['Q3-75%'] = np.percentile(data[col],75)
    description[col]['Q4-100%'] = np.percentile(data[col],100)
    description[col]['IQR'] = description[col]['Q3-75%'] - description[col]['Q1-25%']
    description[col]['1.5Range'] = 1.5*description[col]['IQR']
    description[col]['Lesser'] = description[col]['Q1-25%'] - description[col]['1.5Range']
    description[col]['Greater'] = description[col]['Q3-75%'] + description[col]['1.5Range']
    description[col]['Min'] = data[col].min()
    description[col]['Max'] = data[col].max()

# %%
description
# Out:
#            sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Mean         108  67.3034  66.3332  66.3702  72.1006  62.2782  198702
# Median       108       67       65       66       71       62  240000
# Mode           1       62       63       65       60     56.7       0
# Q1-25%      54.5     60.6     60.9       61       60   57.945       0
# Q2-50%       108       67       65       66       71       62  240000
# Q3-75%     161.5     75.7       73       72     83.5   66.255  282500
# 99%       212.86       87    91.86    83.86       97  76.1142  629000
# Q4-100%      215     89.4     97.7       91       98    77.89  940000
# IQR          107     15.1     12.1       11     23.5     8.31  282500
# Lesser      -106    37.95    42.75     44.5    24.75    45.48 -423750
# Greater      322    98.35    91.15     88.5   118.75    78.72  706250
# 1.5Range   160.5    22.65    18.15     16.5    35.25   12.465  423750
# ...

# %% [markdown]
# # Finding Outliers

# %%
# Finding the columns with lesser and greater outliers

Lesser = []
Greater = []

for col in Quan:
    if description[col]['Min'] < description[col]['Lesser']:
        Lesser.append(col)
    if description[col]['Max'] > description[col]['Greater']:
        Greater.append(col)

# %%
Lesser
# Out:
# ['hsc_p']

# %%
Greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# # Replacing Outliers

# %%
# Replacing the outlier values

for col in Lesser:
    data[col][data[col] < description[col]['Lesser']] = description[col]['Lesser']
for col in Greater:
    data[col][data[col] > description[col]['Greater']] = description[col]['Greater']
# Out:
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Verifying the data update for Outliers

# %%
# Creating the table for data description manually

description = pd.DataFrame(index = ['Mean', 'Median', 'Mode', 'Q1-25%', 'Q2-50%', 'Q3-75%', '99%', 'Q4-100%', 'IQR', 
                                   'Lesser', 'Greater', '1.5Range', 'Min', 'Max'], columns = Quan)
description
# Out:
#          sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1-25%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2-50%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3-75%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 99%        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4-100%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# IQR        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Lesser     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Greater    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 1.5Range   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Min        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Max        NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
# Filling the descriptive table with respective values

for col in Quan:
    description[col]['Mean'] = data[col].mean()
    description[col]['Median'] = data[col].median()
    description[col]['Mode'] = data[col].mode()[0]
    description[col]['Q1-25%'] = np.percentile(data[col],25)
    description[col]['Q2-50%'] = np.percentile(data[col],50)
    description[col]['99%'] = np.percentile(data[col],99)
    description[col]['Q3-75%'] = np.percentile(data[col],75)
    description[col]['Q4-100%'] = np.percentile(data[col],100)
    description[col]['IQR'] = description[col]['Q3-75%'] - description[col]['Q1-25%']
    description[col]['1.5Range'] = 1.5*description[col]['IQR']
    description[col]['Lesser'] = description[col]['Q1-25%'] - description[col]['1.5Range']
    description[col]['Greater'] = description[col]['Q3-75%'] + description[col]['1.5Range']
    description[col]['Min'] = data[col].min()
    description[col]['Max'] = data[col].max()

# %%
description
# Out:
#            sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Mean         108  67.3034  66.3347  66.3586  72.1006  62.2782  197615
# Median       108       67       65       66       71       62  240000
# Mode           1       62       63       65       60     56.7       0
# Q1-25%      54.5     60.6     60.9       61       60   57.945       0
# Q2-50%       108       67       65       66       71       62  240000
# Q3-75%     161.5     75.7       73       72     83.5   66.255  282500
# 99%       212.86       87   91.129    83.86       97  76.1142  629000
# Q4-100%      215     89.4    91.15     88.5       98    77.89  706250
# IQR          107     15.1     12.1       11     23.5     8.31  282500
# Lesser      -106    37.95    42.75     44.5    24.75    45.48 -423750
# Greater      322    98.35    91.15     88.5   118.75    78.72  706250
# 1.5Range   160.5    22.65    18.15     16.5    35.25   12.465  423750
# ...

# %%
# Finding the columns with lesser and greater outliers

Lesser = []
Greater = []

for col in Quan:
    if description[col]['Min'] < description[col]['Lesser']:
        Lesser.append(col)
    if description[col]['Max'] > description[col]['Greater']:
        Greater.append(col)

# %%
Lesser
# Out:
# []

# %%
Greater
# Out:
# []

# %% [markdown]
# # Frequency | Relative Frequency | Cumulative Frequency

# %%
# Creating a table for Frequency, Relative Frequency, and Cumulative Frequency

freqtable = pd.DataFrame(columns = ['Unique Values', 'Frequency', 'Relative Frequency', 'Cumulative Frequency'])

# %%
# Finding the frequency , Relative Frequency, and Cumulative Frequency for ssc_p

freqtable['Unique Values'] = data['ssc_p'].value_counts().index
freqtable['Frequency'] = data['ssc_p'].value_counts().values
freqtable['Relative Frequency'] = (freqtable['Frequency']/215)
freqtable['Cumulative Frequency'] = freqtable['Relative Frequency'].cumsum()

# %%
freqtable
# Out:
#      Unique Values  Frequency  Relative Frequency  Cumulative Frequency
# 0            62.00         11            0.051163              0.051163
# 1            63.00         10            0.046512              0.097674
# 2            67.00          9            0.041860              0.139535
# 3            52.00          9            0.041860              0.181395
# 4            73.00          9            0.041860              0.223256
# ..             ...        ...                 ...                   ...
# 98           80.60          1            0.004651              0.981395
# 99           65.20          1            0.004651              0.986047
# 100          80.40          1            0.004651              0.990698
# 101          59.96          1            0.004651              0.995349
# 102          78.50          1            0.004651              1.000000
#
# [103 rows x 4 columns]

# %% [markdown]
# # Skewness and Kurtosis

# %%
# Finding the skewness of a column 

data['hsc_p'].skew()
# Out:
# 0.16261050623024148

# %%
# Finding the kurtosis of a column

data['hsc_p'].kurtosis()
# Out:
# 0.08690077018906717

# %%
# Creating the table for data description manually

description = pd.DataFrame(index = ['Mean', 'Median', 'Mode', 'Q1-25%', 'Q2-50%', 'Q3-75%', '99%', 'Q4-100%', 'IQR', 
                                   'Lesser', 'Greater', '1.5Range', 'Min', 'Max', 'Skew','Kurtosis'], columns = Quan)
description
# Out:
#          sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1-25%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2-50%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3-75%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 99%        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4-100%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# IQR        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Lesser     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Greater    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 1.5Range   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Min        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Max        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Skew       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# ...

# %%
# Adding the skewness and kurtosis of each column in the descriptive table

for col in Quan:
    description[col]['Mean'] = data[col].mean()
    description[col]['Median'] = data[col].median()
    description[col]['Mode'] = data[col].mode()[0]
    description[col]['Q1-25%'] = np.percentile(data[col],25)
    description[col]['Q2-50%'] = np.percentile(data[col],50)
    description[col]['99%'] = np.percentile(data[col],99)
    description[col]['Q3-75%'] = np.percentile(data[col],75)
    description[col]['Q4-100%'] = np.percentile(data[col],100)
    description[col]['IQR'] = description[col]['Q3-75%'] - description[col]['Q1-25%']
    description[col]['1.5Range'] = 1.5*description[col]['IQR']
    description[col]['Lesser'] = description[col]['Q1-25%'] - description[col]['1.5Range']
    description[col]['Greater'] = description[col]['Q3-75%'] + description[col]['1.5Range']
    description[col]['Min'] = data[col].min()
    description[col]['Max'] = data[col].max()
    description[col]['Skew'] = data[col].skew()
    description[col]['Kurtosis'] = data[col].kurtosis()

# %%
description
# Out:
#            sl_no     ssc_p      hsc_p   degree_p   etest_p     mba_p  \
# Mean         108   67.3034    66.3347    66.3586   72.1006   62.2782
# Median       108        67         65         66        71        62
# Mode           1        62         63         65        60      56.7
# Q1-25%      54.5      60.6       60.9         61        60    57.945
# Q2-50%       108        67         65         66        71        62
# Q3-75%     161.5      75.7         73         72      83.5    66.255
# 99%       212.86        87     91.129      83.86        97   76.1142
# Q4-100%      215      89.4      91.15       88.5        98     77.89
# IQR          107      15.1       12.1         11      23.5      8.31
# Lesser      -106     37.95      42.75       44.5     24.75     45.48
# Greater      322     98.35      91.15       88.5    118.75     78.72
# 1.5Range   160.5     22.65      18.15       16.5     35.25    12.465
# Min            1     40.89      42.75         50        50     51.21
# ...

# %% [markdown]
# # Variance and Standard Deviation

# %%
data['ssc_p'].var()
# Out:
# 117.2283767354923

# %%
data['ssc_p'].std()
# Out:
# 10.827205398231452

# %%
# Creating the table for data description manually

description = pd.DataFrame(index = ['Mean', 'Median', 'Mode', 'Q1-25%', 'Q2-50%', 'Q3-75%', '99%', 'Q4-100%', 'IQR', 
                                   'Lesser', 'Greater', '1.5Range', 'Min', 'Max', 'Skew','Kurtosis', 'var', 'std'],
                           columns = Quan)
description
# Out:
#          sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1-25%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2-50%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3-75%     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 99%        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4-100%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# IQR        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Lesser     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Greater    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 1.5Range   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Min        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Max        NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Skew       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# ...

# %%
# Adding the skewness and kurtosis of each column in the descriptive table

for col in Quan:
    description[col]['Mean'] = data[col].mean()
    description[col]['Median'] = data[col].median()
    description[col]['Mode'] = data[col].mode()[0]
    description[col]['Q1-25%'] = np.percentile(data[col],25)
    description[col]['Q2-50%'] = np.percentile(data[col],50)
    description[col]['99%'] = np.percentile(data[col],99)
    description[col]['Q3-75%'] = np.percentile(data[col],75)
    description[col]['Q4-100%'] = np.percentile(data[col],100)
    description[col]['IQR'] = description[col]['Q3-75%'] - description[col]['Q1-25%']
    description[col]['1.5Range'] = 1.5*description[col]['IQR']
    description[col]['Lesser'] = description[col]['Q1-25%'] - description[col]['1.5Range']
    description[col]['Greater'] = description[col]['Q3-75%'] + description[col]['1.5Range']
    description[col]['Min'] = data[col].min()
    description[col]['Max'] = data[col].max()
    description[col]['Skew'] = data[col].skew()
    description[col]['Kurtosis'] = data[col].kurtosis()
    description[col]['var'] = data[col].var()
    description[col]['std'] = data[col].std()

# %%
description
# Out:
#             sl_no     ssc_p      hsc_p   degree_p   etest_p     mba_p  \
# Mean          108   67.3034    66.3347    66.3586   72.1006   62.2782
# Median        108        67         65         66        71        62
# Mode            1        62         63         65        60      56.7
# Q1-25%       54.5      60.6       60.9         61        60    57.945
# Q2-50%        108        67         65         66        71        62
# Q3-75%      161.5      75.7         73         72      83.5    66.255
# 99%        212.86        87     91.129      83.86        97   76.1142
# Q4-100%       215      89.4      91.15       88.5        98     77.89
# IQR           107      15.1       12.1         11      23.5      8.31
# Lesser       -106     37.95      42.75       44.5     24.75     45.48
# Greater       322     98.35      91.15       88.5    118.75     78.72
# 1.5Range    160.5     22.65      18.15       16.5     35.25    12.465
# ...

# %% [markdown]
# # Probability Density Function
#              Tells about the probability of particular range

# %%
# Plotting the distribution graph

sns.distplot(data['ssc_p'])
# Out:
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sns.distplot(data['etest_p'])
# Out:
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
# Calculating the probability density function

from scipy.stats import norm

ax1 = sns.distplot(data['ssc_p'],kde= True, kde_kws = {'color':'green'}, color = 'yellow')
plt.axvline(60, color = 'red')
plt.axvline(70, color = 'red')

# Generating sample data

sample =data

# Calculating the parameters

sample_mean = sample['ssc_p'].mean()
sample_std = sample['ssc_p'].std()
print("\t Mean =%.3f \n Standard_Deviation =%.3f" %  (sample_mean, sample_std))

# Defining the didtribution

dist = norm(sample_mean, sample_std)

# Sample probability for the given range of outcomes

probabilities = []
for value in range (60,70):
    probability = dist.pdf(value)
    probabilities.append(probability)
prob = sum(probabilities)
print ('The area between the range {} to {} is: {}'.format (60,70,prob))
# Out:
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# 	 Mean =67.303
#  Standard_Deviation =10.827
# The area between the range 60 to 70 is: 0.3449514151280293

# %%
# Creating a function for probability density function

def get_pdf(data,startrange,endrange):
    
    import matplotlib.pyplot as plt
    import seaborn as sns
    from scipy.stats import norm
    
    plot = sns.distplot(data, kde = True, kde_kws = {'color' : 'blue'}, color = 'green')
    plt.axvline(startrange, color = 'red')
    plt.axvline(endrange, color = 'red')
    
    # Generating the sample data
    
    sample = data
    
    # Calculating the parameters
    
    sample_mean = sample.mean()
    sample_std = sample.std()
    print('\t Mean = %.3f \n Standard Deviation = %.3f '% (sample_mean,sample_std))
    
    # Define the distribution
    
    dist = norm(sample_mean, sample_std)
    
    # Sample probability for the given range of outcomes
    
    probabilities = []
    for value in range(startrange, endrange):
        probability = dist.pdf(value)
        probabilities.append(probability)
    prob = sum(probabilities)
    print('The area between the given range {} to {} is: {}'.format (startrange, endrange, prob))
    return prob

# %%
get_pdf(data['hsc_p'], 50, 60)
# Out:
# 	 Mean = 66.335
#  Standard Deviation = 10.586
# The area between the given range 50 to 60 is: 0.20335972385849235
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   if __name__ == "__main__":
# 0.20335972385849235

# %% [markdown]
# # Cumulative Density Function

# %%
# Installing statsmodels

# !pip install statsmodels

# %%
# Calculating Empirical cumulative density function

from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(data['ssc_p'])
ecdf(78)
# Out:
# 0.827906976744186

# %% [markdown]
# # Standard Normal Distribution

# %%
# Converting to standard normal distribution


Mean = data['hsc_p'].mean()
Std = data['hsc_p'].std()

z_scores = []
for i in data['hsc_p']:
    z_score = (i - Mean) / Std
    z_scores.append(z_score)

# Plotting the distribution of z-scores
sns.distplot(z_scores, kde=True)

# Calculating the average of the z-scores
average_z_score = sum(z_scores) / len(z_scores)
average_z_score
# Out:
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   del sys.path[0]
# -8.649411936033196e-16

# %%
# Creating a function for Converting to standard normal distribution

def stdND_graph(data):
    import seaborn as sns
    Mean = data.mean()
    Std = data.std()
    
    z_scores = []
    for values in data:
        z_score = (values-Mean)/Std
        z_scores.append(z_score)
        
# Plotting the distribution of z_scores

    sns.distplot (z_scores, kde = True)

# Calculating the average of z_scores

    average_z_scores = sum(z_scores)/len(z_scores)
    return average_z_scores

# %%
stdND_graph(data['hsc_p'])
# Out:
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   from ipykernel import kernelapp as app
# -8.649411936033196e-16
